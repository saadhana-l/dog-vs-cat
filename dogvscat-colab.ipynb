# %%
import tensorflow as tf
import dataset

# %%
from google.colab import drive,files

# %%
# !pip install dataset
# Out:
# Collecting dataset
#   Downloading https://files.pythonhosted.org/packages/d5/02/a4c77a15d004f1307a579e577974fa9292a63e93abff3e40ad993cf597c7/dataset-1.1.2-py2.py3-none-any.whl
# Collecting alembic>=0.6.2 (from dataset)
#   Downloading https://files.pythonhosted.org/packages/6e/8b/fa3bd058cccd5e9177fea4efa26bfb769228fdd3178436ad5e05830ef6ef/alembic-1.0.10.tar.gz (1.0MB)
#      |████████████████████████████████| 1.0MB 5.1MB/s
# Requirement already satisfied: sqlalchemy>=1.1.2 in /usr/local/lib/python3.6/dist-packages (from dataset) (1.3.4)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from dataset) (1.12.0)
# Collecting Mako (from alembic>=0.6.2->dataset)
#   Downloading https://files.pythonhosted.org/packages/37/d7/2287b48aaeccdf2c75040fa5db69f6fad1877483aa6ce68316ab959ad1a0/Mako-1.0.11.tar.gz (461kB)
#      |████████████████████████████████| 471kB 44.9MB/s
# Collecting python-editor>=0.3 (from alembic>=0.6.2->dataset)
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic>=0.6.2->dataset) (2.5.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic>=0.6.2->dataset) (1.1.1)
# Building wheels for collected packages: alembic, Mako
#   Building wheel for alembic (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/de/cf/b3/0eb5c89ea6aa1b49cb41315f9ec139ada8cbffd575bf170d43
#   Building wheel for Mako (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/b4/cb/4b/b64eabdf5c11ecb491a37c72819148976f276d323ca12bcaf4
# Successfully built alembic Mako
# Installing collected packages: Mako, python-editor, alembic, dataset
# Successfully installed Mako-1.0.11 alembic-1.0.10 dataset-1.1.2 python-editor-1.0.4

# %%
pwd
# Out:
# '/content'

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import dataset

# %%
a = tf.truncated_normal([16,128,128,3])
sess = tf.Session()
sess.run(tf.initialize_all_variables())
sess.run(tf.shape(a))
# Out:
# array([ 16, 128, 128,   3], dtype=int32)

# %%
b=tf.reshape(a,[16,49152])
sess.run(tf.shape(b))
# Out:
# array([   16, 49152], dtype=int32)

# %%
x = [0., -1., 2., 3.]
softmax_x = tf.nn.softmax(x)
print(x)
print("SOFTMAX X")
print(sess.run(softmax_x))
# Out:
# [0.0, -1.0, 2.0, 3.0]
# SOFTMAX X
# [0.03467109 0.01275478 0.25618663 0.69638747]

# %%
pwd
# Out:
# '/content'

# %%
classes = ['dogs', 'cats']
num_classes = len(classes)
 
train_path='train'
 
# validation split
validation_size = 0.2
 
# batch size
batch_size = 16
 
data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-4edb4726c94e> in <module>()
#      10 batch_size = 16
#      11
# ---> 12 data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
#
# AttributeError: module 'dataset' has no attribute 'read_train_sets'

# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Convolution2D

# %%
from keras.layers import MaxPooling2D

# %%
from keras.layers import Flatten

# %%
from keras.layers import Dense

# %%
classifier=Sequential()
classifier.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(units=128,activation='relu'))

# %%
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory(
   "/content/drive/My Drive/dogvscat/dataset/training_set",
    target_size=(64,64),
    batch_size=32,
    class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-f278c52b946e> in <module>()
#       3     target_size=(64,64),
#       4     batch_size=32,
# ----> 5     class_mode='binary')
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     536             follow_links=follow_links,
#     537             subset=subset,
# --> 538             interpolation=interpolation
#     539         )
#     540
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/directory_iterator.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     103         if not classes:
#     104             classes = []
# --> 105             for subdir in sorted(os.listdir(directory)):
#     106                 if os.path.isdir(os.path.join(directory, subdir)):
#     107                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\content\\drive\\My Drive\\dogvscat\\dataset\\training_set'

# %%
test_set=test_datagen.flow_from_directory(
    'dataset/test_set',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary')

# %%
from IPython.display import display

# %%
from PIL import Image

# %%
classifier.fit_generator(training_set,steps_per_epoch=320,epochs=10,validation_data=test_set,validation_steps=800)

# %%
import numpy as np

# %%
from keras.preprocessing import image

# %%
test_im=image.load_img('random.jpeg',target_size=(64,64))

# %%
test_im=image.img_to_array(test_im)

# %%
test_im=np.expand_dims(test_im,axis=0)

# %%
result=classifier.predict_proba(test_im)
print(result)

# %%
training_set.class_indices

# %%
if result[0][0]>=0.5:
    prediction='dog'
else:
    prediction='cat'
print(result[0][0])

# %%
print(prediction)

# %%
test_ima=image.load_img('rand2.jpg',target_size=(64,64))

# %%
test_ima=image.img_to_array(test_ima)
test_ima=np.expand_dims(test_ima,axis=0)

# %%
resultt=classifier.predict_proba(test_ima)
print(resultt)

# %%
training_set.class_indices

# %%
if resultt[0][0]>=0.5:
    prediction='dog'
else:
    prediction='cat'
print(resultt[0][0])

# %%
print(prediction)

# %%
test_image=image.load_img('krishna.jpg',target_size=(64,64))

# %%
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)

# %%
resultkrishna=classifier.predict_proba(test_image)
print(resultkrishna)

# %%
test_image=image.load_img('krishnacat.jpg',target_size=(64,64))

# %%
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)

# %%
resultkrishna=classifier.predict(test_image)
print(resultkrishna)

# %%
test_image2=image.load_img('krishnadog.jpg',target_size=(64,64))

# %%
test_image2=image.img_to_array(test_image2)
test_image2=np.expand_dims(test_image2,axis=0)

# %%
res=classifier.predict(test_image2)
print(res)

# %%
test_image3=image.load_img('krishnacat.jpg',target_size=(64,64))

# %%
test_image3=image.img_to_array(test_image3)
test_image3=np.expand_dims(test_image3,axis=0)

# %%
resu=classifier.predict(test_image3)
print(resu)

# %%
test_image4=image.load_img('krishnaaa.jpg',target_size=(64,64))

# %%
test_image4=image.img_to_array(test_image4)
test_image4=np.expand_dims(test_image4,axis=0)

# %%
resul=classifier.predict(test_image4)
print(resu)

# %%
test_image5=image.load_img('krishna.jpg',target_size=(64,64))

# %%
test_image5=image.img_to_array(test_image5)
test_image5=np.expand_dims(test_image5,axis=0)

# %%
resultkrish=classifier.predict_proba(test_image5)
print(resultkrish)

# %%
test_image6=image.load_img('rama.jpg',target_size=(64,64))

# %%
test_image6=image.img_to_array(test_image6)
test_image6=np.expand_dims(test_image6,axis=0)

# %%
resultram=classifier.predict_proba(test_image6)
print(resultram)
